# %% [markdown]
# # Dataset loading
#
# ### *try-catch*
# Loading and filtering the whole dataset of songs from WASABI'S API

# %%
import requests
import pandas as pd
from urllib.request import urlopen
import json

# %%
# load chunks of 200 songs from the API 5500 times (maximum reached)
k=0
data = ''
for i in range(5500):
  k += 200 * i
  api_url = str('https://wasabi.i3s.unice.fr/api/v1/song_all/'+str(k)+'?project=_id,title,name,rank,publicationDate,language_detect, genre')
  response = requests.get(api_url)

  # Check for a successful response (HTTP status code 200)
  if response.status_code == 200:
      data = response.json()  # Parse the JSON response
  else:
      print("Error: Unable to fetch data from the API.")
      data = None
  if data is not None:
    # concatenate loaded data into a dataframe
    df = pd.concat([df, pd.DataFrame(data)], axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8d7d10e608b5> in <cell line: 4>()
#       5   k += 200 * i
#       6   api_url = str('https://wasabi.i3s.unice.fr/api/v1/song_all/'+str(k)+'?project=_id,title,name,rank,publicationDate,language_detect, genre')
# ----> 7   response = requests.get(api_url)
#       8
#       9   # Check for a successful response (HTTP status code 200)
#
# NameError: name 'requests' is not defined

# %%
df
# Out:
#                           _id               name                    title  \
# 0    5714dec325ac0d8aee3806db  A Case Of Grenada          Traitors Manual
# 1    5714dec325ac0d8aee3806dc  A Case Of Grenada   As Far As We Can't See
# 2    5714dec325ac0d8aee3806dd             A Camp           Frequent Flyer
# 3    5714dec325ac0d8aee3806de             A Camp            I Can Buy You
# 4    5714dec325ac0d8aee3806df             A Camp         Angel Of Sadness
# ..                        ...                ...                      ...
# 195  5714deed25ac0d8aee57e1ec                 Yö  Kuinka SElvitä Hengissä
# 196  5714deed25ac0d8aee57e1ed                 Yö              Satelliitit
# 197  5714deed25ac0d8aee57e1ee                 Yö         Sateenkaaren Pää
# 198  5714deed25ac0d8aee57e1ef                 Yö             Hetki Kahden
# 199  5714deed25ac0d8aee57e1f0                 Yö    Ansaan Vielä Sut Saan
#
#          rank publicationDate language_detect
# ...

# %%
# retrieve only the songs in english
df_eng = df[df['language_detect'] == 'english']
df_eng
# Out:
#                          _id            name  \
# 0   5714dec325ac0d8aee3804e7               A
# 1   5714dec325ac0d8aee3804e8               A
# 2   5714dec325ac0d8aee3804e9               A
# 3   5714dec325ac0d8aee3804ea               A
# 4   5714dec325ac0d8aee3804eb               A
# ..                       ...             ...
# 36  5714deed25ac0d8aee57e14d  Yvonne Elliman
# 37  5714deed25ac0d8aee57e14e  Yvonne Elliman
# 38  5714deed25ac0d8aee57e14f              YZ
# 39  5714deed25ac0d8aee57e150              YZ
# 70  5714deed25ac0d8aee57e16f  Yüksek Sadakat
#
#                                  title      rank publicationDate  \
# 0                           Turn It Up  261631.0      1998-06-22
# 1                              Foghorn  297455.0      1998-06-22
# 2                        Cheeky Monkey  268232.0      1998-06-22
# 3                                No. 1  308436.0      1998-06-22
# 4                             Bad Idea  273805.0      1998-06-22
# ...

# %%
# retrieve only the songs that have a concrete publication date
df_eng1= df_eng[df_eng['publicationDate'].str.len() > 0]
df_eng1 =df_eng1[df_eng1['publicationDate'] != '0000-00-00']
df_eng1
# Out:
#                          _id            name                   title  \
# 0   5714dec325ac0d8aee3804e7               A              Turn It Up
# 1   5714dec325ac0d8aee3804e8               A                 Foghorn
# 2   5714dec325ac0d8aee3804e9               A           Cheeky Monkey
# 3   5714dec325ac0d8aee3804ea               A                   No. 1
# 4   5714dec325ac0d8aee3804eb               A                Bad Idea
# ..                       ...             ...                     ...
# 23  5714deed25ac0d8aee57e140  Yvonne Elliman              Love Pains
# 24  5714deed25ac0d8aee57e141  Yvonne Elliman                Savannah
# 27  5714deed25ac0d8aee57e144  Yvonne Elliman  Everything Must Change
# 37  5714deed25ac0d8aee57e14e  Yvonne Elliman        Moment By Moment
# 70  5714deed25ac0d8aee57e16f  Yüksek Sadakat              Live It Up
#
#         rank publicationDate language_detect
# 0   261631.0      1998-06-22         english
# 1   297455.0      1998-06-22         english
# ...

# %%
# retrieve the songs that have a concrete ranking
df_eng0= df_eng1[df_eng1['rank'] > 0.0]
df_eng0
# Out:
#                          _id            name                   title  \
# 0   5714dec325ac0d8aee3804e7               A              Turn It Up
# 1   5714dec325ac0d8aee3804e8               A                 Foghorn
# 2   5714dec325ac0d8aee3804e9               A           Cheeky Monkey
# 3   5714dec325ac0d8aee3804ea               A                   No. 1
# 4   5714dec325ac0d8aee3804eb               A                Bad Idea
# ..                       ...             ...                     ...
# 22  5714deed25ac0d8aee57e13f  Yvonne Elliman           Sailing Ships
# 23  5714deed25ac0d8aee57e140  Yvonne Elliman              Love Pains
# 24  5714deed25ac0d8aee57e141  Yvonne Elliman                Savannah
# 27  5714deed25ac0d8aee57e144  Yvonne Elliman  Everything Must Change
# 37  5714deed25ac0d8aee57e14e  Yvonne Elliman        Moment By Moment
#
#         rank publicationDate language_detect
# 0   261631.0      1998-06-22         english
# 1   297455.0      1998-06-22         english
# ...

# %%
# save the dataset in a CSV format
file_path = 'filtered_songs.csv'

df_eng0.to_csv(file_path, index=False)
